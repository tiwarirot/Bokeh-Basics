# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
N = 4000

# %%
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5

# %%
X = x.astype(int)
Y = y.astype(int)
r = radii.astype(int)

# %%
colors = ['#%02X%02X%02X' % (r,g,150) for r, g in zip((50+2*X), (30+2*Y))]

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="180d6e9c-44f7-4e5f-8568-23d6498debae">Loading BokehJS ...</span>
#     </div>

# %%
p = figure()
p.circle(X, Y, radius=r, fill_color=colors, fill_alpha=0.6, line_color=None)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='c4f446fe-2019-4c03-90ba-c1b2e64340e6',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='6371e084-23d0-407f-b1fc-9bf5826aee30',
#         callback=None,
#         data={'fill_color': ['#64C096',
#           '#969496',
#           '#8A9096',
#           '#48A896',
#           '#385E96',
#           '#DADA96',
#           '#942296',
#           '#76C096',
#           '#407C96',
#           '#5E8496',
#           '#66CA96',
#           '#3CC896',
#           '#966096',
#           '#50DA96',
#           '#C2A296',
#           '#806096',
#           '#B26096',
#           '#AC4C96',
#           '#461E96',
#           '#402096',
#           '#C4CC96',
#           '#705296',
#           '#F69296',
#           '#34AE96',
#           '#EE2C96',
#           '#D4B896',
#           '#726096',
#           '#E27296',
#           '#944096',
#           '#586496',
#           '#363A96',
#           '#A25C96',
#           '#8E8896',
#           '#BC3496',
#           '#DE3896',
#           '#D69296',
#           '#406E96',
#           '#CE1E96',
#           '#749296',
#           '#705E96',
#           '#B8AA96',
#           '#509A96',
#           '#5E5496',
#           '#64A896',
#           '#866696',
#           '#B22496',
#           '#E6D496',
#           '#383E96',
#           '#6AE296',
#           '#96C896',
#           '#3CD696',
#           '#9A2896',
#           '#3AC896',
#           '#B05496',
#           '#6CC896',
#           '#4A4A96',
#           '#AE2296',
#           '#92A496',
#           '#763E96',
#           '#D24496',
#           '#CCCA96',
#           '#5AC096',
#           '#6AE496',
#           '#9A7496',
#           '#5A4096',
#           '#AE2096',
#           '#D6CC96',
#           '#945896',
#           '#726296',
#           '#924C96',
#           '#D47496',
#           '#5ACE96',
#           '#A48496',
#           '#AC9096',
#           '#F8BE96',
#           '#9C4696',
#           '#727296',
#           '#469C96',
#           '#485496',
#           '#D8CE96',
#           '#DE8C96',
#           '#C0AC96',
#           '#E4D696',
#           '#949696',
#           '#D2E496',
#           '#E27C96',
#           '#9C6E96',
#           '#8A9896',
#           '#765896',
#           '#B0CA96',
#           '#A6D896',
#           '#523296',
#           '#4ECA96',
#           '#602A96',
#           '#40E296',
#           '#645896',
#           '#D4CC96',
#           '#8C9E96',
#           '#C27896',
#           '#B64696',
#           '#824A96',
#           '#E4C896',
#           '#64CC96',
#           '#E83496',
#           '#B8E096',
#           '#5A4A96',
#           '#7A7696',
#           '#C06A96',
#           '#708696',
#           '#E02A96',
#           '#80BA96',
#           '#745896',
#           '#CC8696',
#           '#A6D696',
#           '#7A6096',
#           '#984896',
#           '#5C2C96',
#           '#42E096',
#           '#40DE96',
#           '#D07096',
#           '#5E5696',
#           '#5A4A96',
#           '#ECC496',
#           '#863096',
#           '#EC9696',
#           '#EEAC96',
#           '#B4A696',
#           '#722E96',
#           '#F8A896',
#           '#E8D696',
#           '#4A3096',
#           '#6CC296',
#           '#F29A96',
#           '#A6BE96',
#           '#9E6C96',
#           '#8A4496',
#           '#D8CE96',
#           '#968496',
#           '#F68496',
#           '#92A296',
#           '#52B296',
#           '#E24496',
#           '#34D496',
#           '#3ADE96',
#           '#6A6096',
#           '#B89C96',
#           '#F6C896',
#           '#D05096',
#           '#802E96',
#           '#9EC896',
#           '#BC8C96',
#           '#A29C96',
#           '#54B296',
#           '#A6D896',
#           '#CA2696',
#           '#8ECE96',
#           '#403C96',
#           '#7EB096',
#           '#D8D896',
#           '#DE2496',
#           '#EC4096',
#           '#AE8696',
#           '#EA4E96',
#           '#CCC896',
#           '#F0DA96',
#           '#984E96',
#           '#345E96',
#           '#9CC296',
#           '#50A496',
#           '#B85A96',
#           '#5C3696',
#           '#88B296',
#           '#866096',
#           '#50AE96',
#           '#BEC696',
#           '#32B696',
#           '#E82A96',
#           '#446E96',
#           '#C6D896',
#           '#6E6696',
#           '#44C296',
#           '#EEDC96',
#           '#BC7A96',
#           '#829C96',
#           '#D22496',
#           '#462C96',
#           '#A85296',
#           '#A29896',
#           '#C6C696',
#           '#B82296',
#           '#E65296',
#           '#BE6696',
#           '#CCA496',
#           '#BA2496',
#           '#862096',
#           '#B4C296',
#           '#E2A296',
#           '#92D296',
#           '#408C96',
#           '#A84296',
#           '#427296',
#           '#464296',
#           '#EAB096',
#           '#E22E96',
#           '#56C496',
#           '#44D496',
#           '#E8A696',
#           '#444E96',
#           '#823696',
#           '#3AA896',
#           '#D89896',
#           '#52DA96',
#           '#B8B096',
#           '#48A096',
#           '#3EB496',
#           '#4AD496',
#           '#E4A096',
#           '#702496',
#           '#529A96',
#           '#BAE096',
#           '#A6C096',
#           '#C82096',
#           '#A65A96',
#           '#444696',
#           '#824496',
#           '#6A6096',
#           '#38D496',
#           '#EE3C96',
#           '#545A96',
#           '#DC9696',
#           '#DEBC96',
#           '#4A9296',
#           '#F05096',
#           '#386C96',
#           '#E45C96',
#           '#54A296',
#           '#486896',
#           '#346C96',
#           '#AC2C96',
#           '#4C9E96',
#           '#66A496',
#           '#DC7496',
#           '#D6D296',
#           '#405496',
#           '#BAA896',
#           '#44CE96',
#           '#A07E96',
#           '#407E96',
#           '#8C2696',
#           '#C43296',
#           '#DE7096',
#           '#804496',
#           '#BE9696',
#           '#B09296',
#           '#AE4A96',
#           '#9A3496',
#           '#B82496',
#           '#9AB496',
#           '#B0B496',
#           '#BEAE96',
#           '#D48696',
#           '#E0E296',
#           '#DE4A96',
#           '#768896',
#           '#42BE96',
#           '#70CC96',
#           '#4AE096',
#           '#429496',
#           '#E4BA96',
#           '#506E96',
#           '#669E96',
#           '#6E4A96',
#           '#565A96',
#           '#DA4896',
#           '#448296',
#           '#B43496',
#           '#AE3896',
#           '#4CCC96',
#           '#764A96',
#           '#389896',
#           '#AEB896',
#           '#CAE096',
#           '#947096',
#           '#622296',
#           '#32CA96',
#           '#C0E296',
#           '#CE5696',
#           '#C03496',
#           '#96A896',
#           '#C45E96',
#           '#842896',
#           '#3E6A96',
#           '#625C96',
#           '#744496',
#           '#B48896',
#           '#F64E96',
#           '#3E2896',
#           '#448896',
#           '#F07896',
#           '#E66296',
#           '#AC6096',
#           '#CA4496',
#           '#78C496',
#           '#968496',
#           '#D0A696',
#           '#C66696',
#           '#8EDC96',
#           '#DC3A96',
#           '#78B896',
#           '#BA2C96',
#           '#BC3496',
#           '#CE2896',
#           '#C09096',
#           '#342896',
#           '#34DC96',
#           '#D44696',
#           '#346E96',
#           '#F23896',
#           '#804C96',
#           '#ECD696',
#           '#86BA96',
#           '#90A696',
#           '#CAA696',
#           '#345896',
#           '#A86C96',
#           '#9C7896',
#           '#7A8A96',
#           '#F47496',
#           '#C85E96',
#           '#7A4C96',
#           '#429896',
#           '#709A96',
#           '#EAD296',
#           '#CE3296',
#           '#C06C96',
#           '#74AA96',
#           '#5EE296',
#           '#F09696',
#           '#9AD696',
#           '#7A2496',
#           '#927096',
#           '#EED896',
#           '#F88496',
#           '#BCCE96',
#           '#A6CC96',
#           '#EE5E96',
#           '#72CE96',
#           '#344E96',
#           '#922E96',
#           '#E29496',
#           '#BCB496',
#           '#EAB496',
#           '#3CD496',
#           '#747C96',
#           '#387096',
#           '#A8B296',
#           '#EC3E96',
#           '#3A4496',
#           '#6C6296',
#           '#B46296',
#           '#66DE96',
#           '#745E96',
#           '#467A96',
#           '#70C696',
#           '#5C7496',
#           '#327896',
#           '#92A696',
#           '#38C096',
#           '#32B096',
#           '#BCA496',
#           '#3CAC96',
#           '#A65696',
#           '#D29696',
#           '#DABC96',
#           '#443096',
#           '#70AA96',
#           '#5C8296',
#           '#966E96',
#           '#CCDE96',
#           '#48AE96',
#           '#3C9A96',
#           '#CE2C96',
#           '#806096',
#           '#E88096',
#           '#649C96',
#           '#7CB096',
#           '#96DA96',
#           '#B0A896',
#           '#685696',
#           '#446096',
#           '#32CE96',
#           '#928696',
#           '#F23896',
#           '#D66896',
#           '#502496',
#           '#B0A096',
#           '#CA9E96',
#           '#844296',
#           '#9A8496',
#           '#A2A096',
#           '#A03A96',
#           '#464896',
#           '#50C296',
#           '#AC7696',
#           '#5AC696',
#           '#A02496',
#           '#5CAA96',
#           '#445E96',
#           '#482696',
#           '#D2E296',
#           '#926096',
#           '#9C2296',
#           '#362496',
#           '#6EAA96',
#           '#908096',
#           '#8ACE96',
#           '#EC4C96',
#           '#C83896',
#           '#F0A496',
#           '#F68896',
#           '#702896',
#           '#9C3496',
#           '#C2B896',
#           '#B6B296',
#           '#78E496',
#           '#588C96',
#           '#444896',
#           '#F0BA96',
#           '#34C896',
#           '#DA8896',
#           '#B62E96',
#           '#6EDC96',
#           '#722A96',
#           '#98CE96',
#           '#8ED496',
#           '#CC6096',
#           '#765C96',
#           '#F03896',
#           '#E68496',
#           '#5C8096',
#           '#625696',
#           '#C4B096',
#           '#A01E96',
#           '#F27696',
#           '#629C96',
#           '#72BC96',
#           '#8C8C96',
#           '#628C96',
#           '#AE9E96',
#           '#807C96',
#           '#AAB296',
#           '#7E4096',
#           '#9CDA96',
#           '#AADA96',
#           '#E2B496',
#           '#D83296',
#           '#C4DA96',
#           '#36A096',
#           '#942E96',
#           '#E69096',
#           '#C46E96',
#           '#66CA96',
#           '#A85896',
#           '#464A96',
#           '#76BE96',
#           '#643496',
#           '#50CA96',
#           '#B04C96',
#           '#5AA096',
#           '#64B896',
#           '#CC5296',
#           '#8C9E96',
#           '#7E6C96',
#           '#D43A96',
#           '#F8DE96',
#           '#A45A96',
#           '#C27496',
#           '#CC5496',
#           '#8ADA96',
#           '#4C8896',
#           '#3AB896',
#           '#D6C896',
#           '#3C1E96',
#           '#DE5A96',
#           '#845E96',
#           '#482296',
#           '#92C096',
#           '#EC9896',
#           '#52D096',
#           '#F48296',
#           '#70AA96',
#           '#C6BE96',
#           '#C03096',
#           '#84C296',
#           '#E42096',
#           '#902296',
#           '#403496',
#           '#4E8496',
#           '#6A3E96',
#           '#384496',
#           '#E03696',
#           '#747496',
#           '#8C3296',
#           '#528896',
#           '#AE6696',
#           '#423096',
#           '#5AD496',
#           '#BEC496',
#           '#C0C096',
#           '#A49C96',
#           '#EC3A96',
#           '#6E8696',
#           '#F2B696',
#           '#3CAE96',
#           '#4C3696',
#           '#84D696',
#           '#545C96',
#           '#F0D696',
#           '#AE3896',
#           '#C42096',
#           '#984296',
#           '#A64696',
#           '#887896',
#           '#467096',
#           '#CA2A96',
#           '#6C6E96',
#           '#8C2C96',
#           '#B86E96',
#           '#3ABC96',
#           '#F8A696',
#           '#605E96',
#           '#542696',
#           '#787696',
#           '#7ECE96',
#           '#486496',
#           '#BC6C96',
#           '#562096',
#           '#388096',
#           '#F29E96',
#           '#F08E96',
#           '#E8B896',
#           '#D43896',
#           '#B27A96',
#           '#3CD096',
#           '#58AA96',
#           '#7E8E96',
#           '#323096',
#           '#604A96',
#           '#6AA696',
#           '#705096',
#           '#54CE96',
#           '#985C96',
#           '#E48E96',
#           '#44CC96',
#           '#7C5896',
#           '#F66096',
#           '#603096',
#           '#585096',
#           '#A06696',
#           '#A4CA96',
#           '#A84A96',
#           '#B8AE96',
#           '#745296',
#           '#AABE96',
#           '#365296',
#           '#663496',
#           '#C26696',
#           '#7A4E96',
#           '#8C9696',
#           '#D4C896',
#           '#748496',
#           '#D64496',
#           '#78BA96',
#           '#D07496',
#           '#82C896',
#           '#624A96',
#           '#72DA96',
#           '#923E96',
#           '#D22096',
#           '#8EC296',
#           '#D67896',
#           '#98E496',
#           '#5ABA96',
#           '#9C7A96',
#           '#E47296',
#           '#D8AE96',
#           '#862896',
#           '#4EE296',
#           '#927696',
#           '#D49A96',
#           '#425896',
#           '#CACA96',
#           '#D08A96',
#           '#3E5096',
#           '#D46496',
#           '#8CA696',
#           '#ACB096',
#           '#7CC096',
#           '#F46096',
#           '#50A096',
#           '#745496',
#           '#869296',
#           '#369096',
#           '#BA3696',
#           '#A62296',
#           '#40E496',
#           '#A24896',
#           '#527896',
#           '#7ECA96',
#           '#DA4896',
#           '#CAD896',
#           '#5C4096',
#           '#742E96',
#           '#C03C96',
#           '#C88296',
#           '#8EB896',
#           '#384496',
#           '#446E96',
#           '#642696',
#           '#D49896',
#           '#5CD696',
#           '#D86496',
#           '#F2D896',
#           '#445496',
#           '#54D696',
#           '#568296',
#           '#4A9096',
#           '#988A96',
#           '#EEDA96',
#           '#8E2496',
#           '#84C096',
#           '#4CDC96',
#           '#BE8296',
#           '#58D096',
#           '#407096',
#           '#BE9E96',
#           '#922C96',
#           '#AC9496',
#           '#767496',
#           '#988696',
#           '#D2E296',
#           '#8A9A96',
#           '#B0A696',
#           '#9A6896',
#           '#869096',
#           '#EC7696',
#           '#F22C96',
#           '#54CC96',
#           '#823C96',
#           '#662096',
#           '#BEAE96',
#           '#98BE96',
#           '#546496',
#           '#60C296',
#           '#F23696',
#           '#A83896',
#           '#5C9696',
#           '#3A4C96',
#           '#EA5296',
#           '#4EAA96',
#           '#C48C96',
#           '#364E96',
#           '#7C2096',
#           '#464A96',
#           '#7ECA96',
#           '#54E296',
#           '#423296',
#           '#8E7896',
#           '#44B296',
#           '#B86E96',
#           '#723096',
#           '#B6E496',
#           '#DC3896',
#           '#5C8696',
#           '#A0BE96',
#           '#AEBE96',
#           '#BA7696',
#           '#AEA096',
#           '#3E4296',
#           '#8C7C96',
#           '#76A096',
#           '#58D896',
#           '#3AAE96',
#           '#A8DE96',
#           '#A22296',
#           '#32A696',
#           '#C6A296',
#           '#3EE096',
#           '#68C896',
#           '#5C3496',
#           '#609296',
#           '#785296',
#           '#489E96',
#           '#7CA096',
#           '#E64696',
#           '#329896',
#           '#F05696',
#           '#A03696',
#           '#B44296',
#           '#505896',
#           '#D06096',
#           '#362296',
#           '#E84C96',
#           '#C67C96',
#           '#9AA496',
#           '#5CBE96',
#           '#528296',
#           '#48BA96',
#           '#A42896',
#           '#A0AA96',
#           '#D45296',
#           '#967A96',
#           '#EC2096',
#           '#DCC496',
#           '#9CA496',
#           '#BE2296',
#           '#F4C496',
#           '#E4D096',
#           '#C8B296',
#           '#58BA96',
#           '#A48E96',
#           '#7E7A96',
#           '#922E96',
#           '#563296',
#           '#B6E496',
#           '#809496',
#           '#D4CC96',
#           '#F44A96',
#           '#CEA296',
#           '#A87896',
#           '#C47696',
#           '#AA9E96',
#           '#648C96',
#           '#AC7696',
#           '#326096',
#           '#AC4696',
#           '#4A8296',
#           '#EC6896',
#           '#F6C696',
#           '#649496',
#           '#349896',
#           '#86B296',
#           '#B48696',
#           '#86D696',
#           '#EAD696',
#           '#D87E96',
#           '#D8E096',
#           '#983296',
#           '#464496',
#           '#F06496',
#           '#E46096',
#           '#766896',
#           '#3E8896',
#           '#908E96',
#           '#3C2696',
#           '#DEE096',
#           '#E08E96',
#           '#A46696',
#           '#DE5496',
#           '#EA6C96',
#           '#947C96',
#           '#F6E496',
#           '#6CD496',
#           '#C05A96',
#           '#92B496',
#           '#907096',
#           '#F89496',
#           '#A6DA96',
#           '#8C3C96',
#           '#A0BC96',
#           '#8C5096',
#           '#324E96',
#           '#CA7E96',
#           '#AC8E96',
#           '#C2E096',
#           '#ECA096',
#           '#561E96',
#           '#8C9496',
#           '#EE7296',
#           '#982496',
#           '#B07096',
#           '#585496',
#           '#60E096',
#           '#582E96',
#           '#F68E96',
#           '#B4CC96',
#           '#7CCC96',
#           '#644896',
#           '#B42896',
#           '#52AE96',
#           '#AAA496',
#           '#E4E296',
#           '#4CA696',
#           '#F03896',
#           '#905896',
#           '#482496',
#           '#E86C96',
#           '#846896',
#           '#84A696',
#           '#D69696',
#           '#E04A96',
#           '#7CCA96',
#           '#3E7096',
#           '#9A7E96',
#           '#CEAA96',
#           '#4A7C96',
#           '#548096',
#           '#406096',
#           '#DACA96',
#           '#8CD496',
#           '#52E096',
#           '#865896',
#           '#D62896',
#           '#4E4496',
#           '#E22E96',
#           '#74D096',
#           '#A26C96',
#           '#86AC96',
#           '#483096',
#           '#E89E96',
#           '#42C096',
#           '#66CE96',
#           '#C0D896',
#           '#704E96',
#           '#B65496',
#           '#DE4E96',
#           '#C43E96',
#           '#E23E96',
#           '#AAA896',
#           '#4E3E96',
#           '#4C5A96',
#           '#BCBA96',
#           '#825A96',
#           '#EE7A96',
#           '#6EB296',
#           '#743096',
#           '#9C8896',
#           '#5AC296',
#           '#805296',
#           '#3EC496',
#           '#E4DE96',
#           '#B6B496',
#           '#38DA96',
#           '#C6A496',
#           '#E2E296',
#           '#6EBA96',
#           '#F06896',
#           '#4C5696',
#           '#88CA96',
#           '#E62296',
#           '#DED496',
#           '#3ED696',
#           '#3AB896',
#           '#F89696',
#           '#9E4896',
#           '#B4B696',
#           '#D63496',
#           '#8EE296',
#           '#DC6296',
#           '#825096',
#           '#8EC896',
#           '#408096',
#           '#DC4E96',
#           '#7E9496',
#           '#C03A96',
#           '#42AC96',
#           '#C27896',
#           '#E25E96',
#           '#A43E96',
#           '#647696',
#           '#E24296',
#           '#D65E96',
#           '#36D896',
#           '#3C2E96',
#           '#E62C96',
#           '#AA9496',
#           '#B6A896',
#           '#D4B496',
#           '#3E7296',
#           '#928496',
#           '#9EDE96',
#           '#B0A896',
#           '#7E8096',
#           '#489896',
#           '#507896',
#           '#BE2A96',
#           '#822C96',
#           '#ECBA96',
#           '#CC7E96',
#           '#BEB096',
#           '#447696',
#           '#548E96',
#           '#3E2696',
#           '#4E5E96',
#           '#F08A96',
#           '#48BE96',
#           '#A42C96',
#           '#365296',
#           '#884E96',
#           '#443496',
#           '#469296',
#           '#D06496',
#           '#768096',
#           '#E66296',
#           '#E8DC96',
#           '#AA9E96',
#           '#F41E96',
#           '#7E9296',
#           '#6E3096',
#           '#F25C96',
#           '#7E5E96',
#           '#7E3296',
#           '#8A8C96',
#           '#505696',
#           '#5CB096',
#           '#327A96',
#           '#AAD296',
#           '#C6CA96',
#           '#C22E96',
#           '#AC6096',
#           '#8A7896',
#           '#90BC96',
#           '#705E96',
#           '#A2C296',
#           '#8A9496',
#           '#5AAC96',
#           '#4A5496',
#           '#EA8A96',
#           '#D47E96',
#           '#E03A96',
#           '#EE7496',
#           '#BAAC96',
#           '#A86296',
#           '#C65096',
#           '#4E4496',
#           '#401E96',
#           '#586C96',
#           '#942096',
#           '#5E8496',
#           '#584C96',
#           '#7EB496',
#           '#642096',
#           '#9A9A96',
#           '#88B896',
#           '#9C4096',
#           '#608C96',
#           '#72B496',
#           '#547C96',
#           '#F2CE96',
#           '#D2AA96',
#           '#D02096',
#           '#3E2096',
#           '#E48696',
#           '#72A496',
#           '#9E6296',
#           '#762E96',
#           '#746E96',
#           '#AA7096',
#           '#42D896',
#           '#A8E096',
#           '#E2C096',
#           '#723496',
#           '#5A3496',
#           '#DEA896',
#           '#609296',
#           '#325E96',
#           '#94D696',
#           '#8E7896',
#           '#669E96',
#           '#D22E96',
#           '#909096',
#           '#EA5A96',
#           '#DCA696',
#           '#D86A96',
#           '#EA4896',
#           '#D8D296',
#           '#6AD696',
#           '#8C2C96',
#           '#3CA096',
#           '#383896',
#           '#822496',
#           '#3E8C96',
#           '#74A096',
#           '#703096',
#           '#AE5496',
#           '#3A7A96',
#           '#A49696',
#           '#3A8296',
#           '#3A6896',
#           '#AC7696',
#           '#E65C96',
#           '#603A96',
#           '#F49C96',
#           '#9ED696',
#           '#A26A96',
#           '#64D696',
#           '#80D096',
#           '#DE3496',
#           '#BE8296',
#           '#769096',
#           ...],
#          'x': {'__ndarray__': '...',
#           'shape': (4000,),
#           'dtype': 'int32'},
#          'y': {'__ndarray__': '...',
#           'shape': (4000,),
#           'dtype': 'int32'},
#          'radius': {'__ndarray__': '...',
#           'shape': (4000,),
#           'dtype': 'int32'}},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='367c8cb2-13a8-445f-ae6f-cc2b372abd90',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='05bf0757-cd1d-4576-8fcc-ca5911847c20',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Circle(
#         id='3c602ee6-b0f5-406e-949b-400be06f2152',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.6},
#         fill_color={'field': 'fill_color'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': None},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width={'value': 1},
#         name=None,
#         radius={'field': 'radius', 'units': 'data'},
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Circle(
#         id='24659584-c4c4-4ada-a599-966ab93f6cee',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width={'value': 1},
#         name=None,
#         radius={'field': 'radius', 'units': 'data'},
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='762f7f09-593d-4685-8c09-24e5f907ef2c',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='6371e084-23d0-407f-b1fc-9bf5826aee30',
#             callback=None,
#             data={'fill_color': ['#64C096',
#               '#969496',
#               '#8A9096',
#               '#48A896',
#               '#385E96',
#               '#DADA96',
#               '#942296',
#               '#76C096',
#               '#407C96',
#               '#5E8496',
#               '#66CA96',
#               '#3CC896',
#               '#966096',
#               '#50DA96',
#               '#C2A296',
#               '#806096',
#               '#B26096',
#               '#AC4C96',
#               '#461E96',
#               '#402096',
#               '#C4CC96',
#               '#705296',
#               '#F69296',
#               '#34AE96',
#               '#EE2C96',
#               '#D4B896',
#               '#726096',
#               '#E27296',
#               '#944096',
#               '#586496',
#               '#363A96',
#               '#A25C96',
#               '#8E8896',
#               '#BC3496',
#               '#DE3896',
#               '#D69296',
#               '#406E96',
#               '#CE1E96',
#               '#749296',
#               '#705E96',
#               '#B8AA96',
#               '#509A96',
#               '#5E5496',
#               '#64A896',
#               '#866696',
#               '#B22496',
#               '#E6D496',
#               '#383E96',
#               '#6AE296',
#               '#96C896',
#               '#3CD696',
#               '#9A2896',
#               '#3AC896',
#               '#B05496',
#               '#6CC896',
#               '#4A4A96',
#               '#AE2296',
#               '#92A496',
#               '#763E96',
#               '#D24496',
#               '#CCCA96',
#               '#5AC096',
#               '#6AE496',
#               '#9A7496',
#               '#5A4096',
#               '#AE2096',
#               '#D6CC96',
#               '#945896',
#               '#726296',
#               '#924C96',
#               '#D47496',
#               '#5ACE96',
#               '#A48496',
#               '#AC9096',
#               '#F8BE96',
#               '#9C4696',
#               '#727296',
#               '#469C96',
#               '#485496',
#               '#D8CE96',
#               '#DE8C96',
#               '#C0AC96',
#               '#E4D696',
#               '#949696',
#               '#D2E496',
#               '#E27C96',
#               '#9C6E96',
#               '#8A9896',
#               '#765896',
#               '#B0CA96',
#               '#A6D896',
#               '#523296',
#               '#4ECA96',
#               '#602A96',
#               '#40E296',
#               '#645896',
#               '#D4CC96',
#               '#8C9E96',
#               '#C27896',
#               '#B64696',
#               '#824A96',
#               '#E4C896',
#               '#64CC96',
#               '#E83496',
#               '#B8E096',
#               '#5A4A96',
#               '#7A7696',
#               '#C06A96',
#               '#708696',
#               '#E02A96',
#               '#80BA96',
#               '#745896',
#               '#CC8696',
#               '#A6D696',
#               '#7A6096',
#               '#984896',
#               '#5C2C96',
#               '#42E096',
#               '#40DE96',
#               '#D07096',
#               '#5E5696',
#               '#5A4A96',
#               '#ECC496',
#               '#863096',
#               '#EC9696',
#               '#EEAC96',
#               '#B4A696',
#               '#722E96',
#               '#F8A896',
#               '#E8D696',
#               '#4A3096',
#               '#6CC296',
#               '#F29A96',
#               '#A6BE96',
#               '#9E6C96',
#               '#8A4496',
#               '#D8CE96',
#               '#968496',
#               '#F68496',
#               '#92A296',
#               '#52B296',
#               '#E24496',
#               '#34D496',
#               '#3ADE96',
#               '#6A6096',
#               '#B89C96',
#               '#F6C896',
#               '#D05096',
#               '#802E96',
#               '#9EC896',
#               '#BC8C96',
#               '#A29C96',
#               '#54B296',
#               '#A6D896',
#               '#CA2696',
#               '#8ECE96',
#               '#403C96',
#               '#7EB096',
#               '#D8D896',
#               '#DE2496',
#               '#EC4096',
#               '#AE8696',
#               '#EA4E96',
#               '#CCC896',
#               '#F0DA96',
#               '#984E96',
#               '#345E96',
#               '#9CC296',
#               '#50A496',
#               '#B85A96',
#               '#5C3696',
#               '#88B296',
#               '#866096',
#               '#50AE96',
#               '#BEC696',
#               '#32B696',
#               '#E82A96',
#               '#446E96',
#               '#C6D896',
#               '#6E6696',
#               '#44C296',
#               '#EEDC96',
#               '#BC7A96',
#               '#829C96',
#               '#D22496',
#               '#462C96',
#               '#A85296',
#               '#A29896',
#               '#C6C696',
#               '#B82296',
#               '#E65296',
#               '#BE6696',
#               '#CCA496',
#               '#BA2496',
#               '#862096',
#               '#B4C296',
#               '#E2A296',
#               '#92D296',
#               '#408C96',
#               '#A84296',
#               '#427296',
#               '#464296',
#               '#EAB096',
#               '#E22E96',
#               '#56C496',
#               '#44D496',
#               '#E8A696',
#               '#444E96',
#               '#823696',
#               '#3AA896',
#               '#D89896',
#               '#52DA96',
#               '#B8B096',
#               '#48A096',
#               '#3EB496',
#               '#4AD496',
#               '#E4A096',
#               '#702496',
#               '#529A96',
#               '#BAE096',
#               '#A6C096',
#               '#C82096',
#               '#A65A96',
#               '#444696',
#               '#824496',
#               '#6A6096',
#               '#38D496',
#               '#EE3C96',
#               '#545A96',
#               '#DC9696',
#               '#DEBC96',
#               '#4A9296',
#               '#F05096',
#               '#386C96',
#               '#E45C96',
#               '#54A296',
#               '#486896',
#               '#346C96',
#               '#AC2C96',
#               '#4C9E96',
#               '#66A496',
#               '#DC7496',
#               '#D6D296',
#               '#405496',
#               '#BAA896',
#               '#44CE96',
#               '#A07E96',
#               '#407E96',
#               '#8C2696',
#               '#C43296',
#               '#DE7096',
#               '#804496',
#               '#BE9696',
#               '#B09296',
#               '#AE4A96',
#               '#9A3496',
#               '#B82496',
#               '#9AB496',
#               '#B0B496',
#               '#BEAE96',
#               '#D48696',
#               '#E0E296',
#               '#DE4A96',
#               '#768896',
#               '#42BE96',
#               '#70CC96',
#               '#4AE096',
#               '#429496',
#               '#E4BA96',
#               '#506E96',
#               '#669E96',
#               '#6E4A96',
#               '#565A96',
#               '#DA4896',
#               '#448296',
#               '#B43496',
#               '#AE3896',
#               '#4CCC96',
#               '#764A96',
#               '#389896',
#               '#AEB896',
#               '#CAE096',
#               '#947096',
#               '#622296',
#               '#32CA96',
#               '#C0E296',
#               '#CE5696',
#               '#C03496',
#               '#96A896',
#               '#C45E96',
#               '#842896',
#               '#3E6A96',
#               '#625C96',
#               '#744496',
#               '#B48896',
#               '#F64E96',
#               '#3E2896',
#               '#448896',
#               '#F07896',
#               '#E66296',
#               '#AC6096',
#               '#CA4496',
#               '#78C496',
#               '#968496',
#               '#D0A696',
#               '#C66696',
#               '#8EDC96',
#               '#DC3A96',
#               '#78B896',
#               '#BA2C96',
#               '#BC3496',
#               '#CE2896',
#               '#C09096',
#               '#342896',
#               '#34DC96',
#               '#D44696',
#               '#346E96',
#               '#F23896',
#               '#804C96',
#               '#ECD696',
#               '#86BA96',
#               '#90A696',
#               '#CAA696',
#               '#345896',
#               '#A86C96',
#               '#9C7896',
#               '#7A8A96',
#               '#F47496',
#               '#C85E96',
#               '#7A4C96',
#               '#429896',
#               '#709A96',
#               '#EAD296',
#               '#CE3296',
#               '#C06C96',
#               '#74AA96',
#               '#5EE296',
#               '#F09696',
#               '#9AD696',
#               '#7A2496',
#               '#927096',
#               '#EED896',
#               '#F88496',
#               '#BCCE96',
#               '#A6CC96',
#               '#EE5E96',
#               '#72CE96',
#               '#344E96',
#               '#922E96',
#               '#E29496',
#               '#BCB496',
#               '#EAB496',
#               '#3CD496',
#               '#747C96',
#               '#387096',
#               '#A8B296',
#               '#EC3E96',
#               '#3A4496',
#               '#6C6296',
#               '#B46296',
#               '#66DE96',
#               '#745E96',
#               '#467A96',
#               '#70C696',
#               '#5C7496',
#               '#327896',
#               '#92A696',
#               '#38C096',
#               '#32B096',
#               '#BCA496',
#               '#3CAC96',
#               '#A65696',
#               '#D29696',
#               '#DABC96',
#               '#443096',
#               '#70AA96',
#               '#5C8296',
#               '#966E96',
#               '#CCDE96',
#               '#48AE96',
#               '#3C9A96',
#               '#CE2C96',
#               '#806096',
#               '#E88096',
#               '#649C96',
#               '#7CB096',
#               '#96DA96',
#               '#B0A896',
#               '#685696',
#               '#446096',
#               '#32CE96',
#               '#928696',
#               '#F23896',
#               '#D66896',
#               '#502496',
#               '#B0A096',
#               '#CA9E96',
#               '#844296',
#               '#9A8496',
#               '#A2A096',
#               '#A03A96',
#               '#464896',
#               '#50C296',
#               '#AC7696',
#               '#5AC696',
#               '#A02496',
#               '#5CAA96',
#               '#445E96',
#               '#482696',
#               '#D2E296',
#               '#926096',
#               '#9C2296',
#               '#362496',
#               '#6EAA96',
#               '#908096',
#               '#8ACE96',
#               '#EC4C96',
#               '#C83896',
#               '#F0A496',
#               '#F68896',
#               '#702896',
#               '#9C3496',
#               '#C2B896',
#               '#B6B296',
#               '#78E496',
#               '#588C96',
#               '#444896',
#               '#F0BA96',
#               '#34C896',
#               '#DA8896',
#               '#B62E96',
#               '#6EDC96',
#               '#722A96',
#               '#98CE96',
#               '#8ED496',
#               '#CC6096',
#               '#765C96',
#               '#F03896',
#               '#E68496',
#               '#5C8096',
#               '#625696',
#               '#C4B096',
#               '#A01E96',
#               '#F27696',
#               '#629C96',
#               '#72BC96',
#               '#8C8C96',
#               '#628C96',
#               '#AE9E96',
#               '#807C96',
#               '#AAB296',
#               '#7E4096',
#               '#9CDA96',
#               '#AADA96',
#               '#E2B496',
#               '#D83296',
#               '#C4DA96',
#               '#36A096',
#               '#942E96',
#               '#E69096',
#               '#C46E96',
#               '#66CA96',
#               '#A85896',
#               '#464A96',
#               '#76BE96',
#               '#643496',
#               '#50CA96',
#               '#B04C96',
#               '#5AA096',
#               '#64B896',
#               '#CC5296',
#               '#8C9E96',
#               '#7E6C96',
#               '#D43A96',
#               '#F8DE96',
#               '#A45A96',
#               '#C27496',
#               '#CC5496',
#               '#8ADA96',
#               '#4C8896',
#               '#3AB896',
#               '#D6C896',
#               '#3C1E96',
#               '#DE5A96',
#               '#845E96',
#               '#482296',
#               '#92C096',
#               '#EC9896',
#               '#52D096',
#               '#F48296',
#               '#70AA96',
#               '#C6BE96',
#               '#C03096',
#               '#84C296',
#               '#E42096',
#               '#902296',
#               '#403496',
#               '#4E8496',
#               '#6A3E96',
#               '#384496',
#               '#E03696',
#               '#747496',
#               '#8C3296',
#               '#528896',
#               '#AE6696',
#               '#423096',
#               '#5AD496',
#               '#BEC496',
#               '#C0C096',
#               '#A49C96',
#               '#EC3A96',
#               '#6E8696',
#               '#F2B696',
#               '#3CAE96',
#               '#4C3696',
#               '#84D696',
#               '#545C96',
#               '#F0D696',
#               '#AE3896',
#               '#C42096',
#               '#984296',
#               '#A64696',
#               '#887896',
#               '#467096',
#               '#CA2A96',
#               '#6C6E96',
#               '#8C2C96',
#               '#B86E96',
#               '#3ABC96',
#               '#F8A696',
#               '#605E96',
#               '#542696',
#               '#787696',
#               '#7ECE96',
#               '#486496',
#               '#BC6C96',
#               '#562096',
#               '#388096',
#               '#F29E96',
#               '#F08E96',
#               '#E8B896',
#               '#D43896',
#               '#B27A96',
#               '#3CD096',
#               '#58AA96',
#               '#7E8E96',
#               '#323096',
#               '#604A96',
#               '#6AA696',
#               '#705096',
#               '#54CE96',
#               '#985C96',
#               '#E48E96',
#               '#44CC96',
#               '#7C5896',
#               '#F66096',
#               '#603096',
#               '#585096',
#               '#A06696',
#               '#A4CA96',
#               '#A84A96',
#               '#B8AE96',
#               '#745296',
#               '#AABE96',
#               '#365296',
#               '#663496',
#               '#C26696',
#               '#7A4E96',
#               '#8C9696',
#               '#D4C896',
#               '#748496',
#               '#D64496',
#               '#78BA96',
#               '#D07496',
#               '#82C896',
#               '#624A96',
#               '#72DA96',
#               '#923E96',
#               '#D22096',
#               '#8EC296',
#               '#D67896',
#               '#98E496',
#               '#5ABA96',
#               '#9C7A96',
#               '#E47296',
#               '#D8AE96',
#               '#862896',
#               '#4EE296',
#               '#927696',
#               '#D49A96',
#               '#425896',
#               '#CACA96',
#               '#D08A96',
#               '#3E5096',
#               '#D46496',
#               '#8CA696',
#               '#ACB096',
#               '#7CC096',
#               '#F46096',
#               '#50A096',
#               '#745496',
#               '#869296',
#               '#369096',
#               '#BA3696',
#               '#A62296',
#               '#40E496',
#               '#A24896',
#               '#527896',
#               '#7ECA96',
#               '#DA4896',
#               '#CAD896',
#               '#5C4096',
#               '#742E96',
#               '#C03C96',
#               '#C88296',
#               '#8EB896',
#               '#384496',
#               '#446E96',
#               '#642696',
#               '#D49896',
#               '#5CD696',
#               '#D86496',
#               '#F2D896',
#               '#445496',
#               '#54D696',
#               '#568296',
#               '#4A9096',
#               '#988A96',
#               '#EEDA96',
#               '#8E2496',
#               '#84C096',
#               '#4CDC96',
#               '#BE8296',
#               '#58D096',
#               '#407096',
#               '#BE9E96',
#               '#922C96',
#               '#AC9496',
#               '#767496',
#               '#988696',
#               '#D2E296',
#               '#8A9A96',
#               '#B0A696',
#               '#9A6896',
#               '#869096',
#               '#EC7696',
#               '#F22C96',
#               '#54CC96',
#               '#823C96',
#               '#662096',
#               '#BEAE96',
#               '#98BE96',
#               '#546496',
#               '#60C296',
#               '#F23696',
#               '#A83896',
#               '#5C9696',
#               '#3A4C96',
#               '#EA5296',
#               '#4EAA96',
#               '#C48C96',
#               '#364E96',
#               '#7C2096',
#               '#464A96',
#               '#7ECA96',
#               '#54E296',
#               '#423296',
#               '#8E7896',
#               '#44B296',
#               '#B86E96',
#               '#723096',
#               '#B6E496',
#               '#DC3896',
#               '#5C8696',
#               '#A0BE96',
#               '#AEBE96',
#               '#BA7696',
#               '#AEA096',
#               '#3E4296',
#               '#8C7C96',
#               '#76A096',
#               '#58D896',
#               '#3AAE96',
#               '#A8DE96',
#               '#A22296',
#               '#32A696',
#               '#C6A296',
#               '#3EE096',
#               '#68C896',
#               '#5C3496',
#               '#609296',
#               '#785296',
#               '#489E96',
#               '#7CA096',
#               '#E64696',
#               '#329896',
#               '#F05696',
#               '#A03696',
#               '#B44296',
#               '#505896',
#               '#D06096',
#               '#362296',
#               '#E84C96',
#               '#C67C96',
#               '#9AA496',
#               '#5CBE96',
#               '#528296',
#               '#48BA96',
#               '#A42896',
#               '#A0AA96',
#               '#D45296',
#               '#967A96',
#               '#EC2096',
#               '#DCC496',
#               '#9CA496',
#               '#BE2296',
#               '#F4C496',
#               '#E4D096',
#               '#C8B296',
#               '#58BA96',
#               '#A48E96',
#               '#7E7A96',
#               '#922E96',
#               '#563296',
#               '#B6E496',
#               '#809496',
#               '#D4CC96',
#               '#F44A96',
#               '#CEA296',
#               '#A87896',
#               '#C47696',
#               '#AA9E96',
#               '#648C96',
#               '#AC7696',
#               '#326096',
#               '#AC4696',
#               '#4A8296',
#               '#EC6896',
#               '#F6C696',
#               '#649496',
#               '#349896',
#               '#86B296',
#               '#B48696',
#               '#86D696',
#               '#EAD696',
#               '#D87E96',
#               '#D8E096',
#               '#983296',
#               '#464496',
#               '#F06496',
#               '#E46096',
#               '#766896',
#               '#3E8896',
#               '#908E96',
#               '#3C2696',
#               '#DEE096',
#               '#E08E96',
#               '#A46696',
#               '#DE5496',
#               '#EA6C96',
#               '#947C96',
#               '#F6E496',
#               '#6CD496',
#               '#C05A96',
#               '#92B496',
#               '#907096',
#               '#F89496',
#               '#A6DA96',
#               '#8C3C96',
#               '#A0BC96',
#               '#8C5096',
#               '#324E96',
#               '#CA7E96',
#               '#AC8E96',
#               '#C2E096',
#               '#ECA096',
#               '#561E96',
#               '#8C9496',
#               '#EE7296',
#               '#982496',
#               '#B07096',
#               '#585496',
#               '#60E096',
#               '#582E96',
#               '#F68E96',
#               '#B4CC96',
#               '#7CCC96',
#               '#644896',
#               '#B42896',
#               '#52AE96',
#               '#AAA496',
#               '#E4E296',
#               '#4CA696',
#               '#F03896',
#               '#905896',
#               '#482496',
#               '#E86C96',
#               '#846896',
#               '#84A696',
#               '#D69696',
#               '#E04A96',
#               '#7CCA96',
#               '#3E7096',
#               '#9A7E96',
#               '#CEAA96',
#               '#4A7C96',
#               '#548096',
#               '#406096',
#               '#DACA96',
#               '#8CD496',
#               '#52E096',
#               '#865896',
#               '#D62896',
#               '#4E4496',
#               '#E22E96',
#               '#74D096',
#               '#A26C96',
#               '#86AC96',
#               '#483096',
#               '#E89E96',
#               '#42C096',
#               '#66CE96',
#               '#C0D896',
#               '#704E96',
#               '#B65496',
#               '#DE4E96',
#               '#C43E96',
#               '#E23E96',
#               '#AAA896',
#               '#4E3E96',
#               '#4C5A96',
#               '#BCBA96',
#               '#825A96',
#               '#EE7A96',
#               '#6EB296',
#               '#743096',
#               '#9C8896',
#               '#5AC296',
#               '#805296',
#               '#3EC496',
#               '#E4DE96',
#               '#B6B496',
#               '#38DA96',
#               '#C6A496',
#               '#E2E296',
#               '#6EBA96',
#               '#F06896',
#               '#4C5696',
#               '#88CA96',
#               '#E62296',
#               '#DED496',
#               '#3ED696',
#               '#3AB896',
#               '#F89696',
#               '#9E4896',
#               '#B4B696',
#               '#D63496',
#               '#8EE296',
#               '#DC6296',
#               '#825096',
#               '#8EC896',
#               '#408096',
#               '#DC4E96',
#               '#7E9496',
#               '#C03A96',
#               '#42AC96',
#               '#C27896',
#               '#E25E96',
#               '#A43E96',
#               '#647696',
#               '#E24296',
#               '#D65E96',
#               '#36D896',
#               '#3C2E96',
#               '#E62C96',
#               '#AA9496',
#               '#B6A896',
#               '#D4B496',
#               '#3E7296',
#               '#928496',
#               '#9EDE96',
#               '#B0A896',
#               '#7E8096',
#               '#489896',
#               '#507896',
#               '#BE2A96',
#               '#822C96',
#               '#ECBA96',
#               '#CC7E96',
#               '#BEB096',
#               '#447696',
#               '#548E96',
#               '#3E2696',
#               '#4E5E96',
#               '#F08A96',
#               '#48BE96',
#               '#A42C96',
#               '#365296',
#               '#884E96',
#               '#443496',
#               '#469296',
#               '#D06496',
#               '#768096',
#               '#E66296',
#               '#E8DC96',
#               '#AA9E96',
#               '#F41E96',
#               '#7E9296',
#               '#6E3096',
#               '#F25C96',
#               '#7E5E96',
#               '#7E3296',
#               '#8A8C96',
#               '#505696',
#               '#5CB096',
#               '#327A96',
#               '#AAD296',
#               '#C6CA96',
#               '#C22E96',
#               '#AC6096',
#               '#8A7896',
#               '#90BC96',
#               '#705E96',
#               '#A2C296',
#               '#8A9496',
#               '#5AAC96',
#               '#4A5496',
#               '#EA8A96',
#               '#D47E96',
#               '#E03A96',
#               '#EE7496',
#               '#BAAC96',
#               '#A86296',
#               '#C65096',
#               '#4E4496',
#               '#401E96',
#               '#586C96',
#               '#942096',
#               '#5E8496',
#               '#584C96',
#               '#7EB496',
#               '#642096',
#               '#9A9A96',
#               '#88B896',
#               '#9C4096',
#               '#608C96',
#               '#72B496',
#               '#547C96',
#               '#F2CE96',
#               '#D2AA96',
#               '#D02096',
#               '#3E2096',
#               '#E48696',
#               '#72A496',
#               '#9E6296',
#               '#762E96',
#               '#746E96',
#               '#AA7096',
#               '#42D896',
#               '#A8E096',
#               '#E2C096',
#               '#723496',
#               '#5A3496',
#               '#DEA896',
#               '#609296',
#               '#325E96',
#               '#94D696',
#               '#8E7896',
#               '#669E96',
#               '#D22E96',
#               '#909096',
#               '#EA5A96',
#               '#DCA696',
#               '#D86A96',
#               '#EA4896',
#               '#D8D296',
#               '#6AD696',
#               '#8C2C96',
#               '#3CA096',
#               '#383896',
#               '#822496',
#               '#3E8C96',
#               '#74A096',
#               '#703096',
#               '#AE5496',
#               '#3A7A96',
#               '#A49696',
#               '#3A8296',
#               '#3A6896',
#               '#AC7696',
#               '#E65C96',
#               '#603A96',
#               '#F49C96',
#               '#9ED696',
#               '#A26A96',
#               '#64D696',
#               '#80D096',
#               '#DE3496',
#               '#BE8296',
#               '#769096',
#               ...],
#              'x': {'__ndarray__': '...',
#               'shape': (4000,),
#               'dtype': 'int32'},
#              'y': {'__ndarray__': '...',
#               'shape': (4000,),
#               'dtype': 'int32'},
#              'radius': {'__ndarray__': '...',
#               'shape': (4000,),
#               'dtype': 'int32'}},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='367c8cb2-13a8-445f-ae6f-cc2b372abd90',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='05bf0757-cd1d-4576-8fcc-ca5911847c20',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="5554c0aa-faf1-4827-a6f1-489f966b090d"></div>
# </div>
